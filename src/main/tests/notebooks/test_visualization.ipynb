# %%
import sys

sys.path.append("../../")

import graphviz

from objects.node import Node
from objects.relationship import Relationship
from objects.data_model import DataModel

# %%
graphviz.__version__, graphviz.version()
# Out:
# ('0.20.1', (10, 0, 1))

# %%
good_nodes = [
            Node(
                label="Person",
                properties=["name", "age"],
                unique_constraints=["name"],
                ),
            Node(
                label="Address", 
                properties=["street", "city"], 
                unique_constraints=None
            ),
            Node(
                label="Pet", 
                properties=["name", "kind"], 
                unique_constraints=None
            ),
            Node(
                label="Toy", 
                properties=["name", "kind"], 
                unique_constraints=["name"]
            )
        ]

good_relationships = [
            Relationship(
                type="HAS_ADDRESS",
                properties=[],
                unique_constraints=None,
                source="Person",
                target="Address",
            ),
            Relationship(
                type="KNOWS",
                unique_constraints=[],
                properties=None,
                source="Person",
                target="Person",
            ),
            Relationship(
                type="HAS_PET",
                unique_constraints=[],
                properties=None,
                source="Person",
                target="Pet",
            ),
            Relationship(
                type="PLAYS_WITH",
                unique_constraints=[],
                properties=None,
                source="Pet",
                target="Toy",
            )
        ]

data_model = DataModel(nodes=good_nodes, relationships=good_relationships)

# %%
data_model
# Out:
# DataModel(nodes=[Node(label='Person', properties=['name', 'age'], unique_constraints=['name']), Node(label='Address', properties=['street', 'city'], unique_constraints=None), Node(label='Pet', properties=['name', 'kind'], unique_constraints=None), Node(label='Toy', properties=['name', 'kind'], unique_constraints=['name'])], relationships=[Relationship(type='HAS_ADDRESS', properties=[], unique_constraints=None, source='Person', target='Address'), Relationship(type='KNOWS', properties=None, unique_constraints=[], source='Person', target='Person'), Relationship(type='HAS_PET', properties=None, unique_constraints=[], source='Person', target='Pet'), Relationship(type='PLAYS_WITH', properties=None, unique_constraints=[], source='Pet', target='Toy')])

# %%
data_model.visualize()
