# %%
import io
import sys
from typing import Dict, List, Union
import pandas as pd
import json
sys.path.append("../")
from llm.llm import LLM

# %%
with open("../data/csv_links.json") as json_file:
    csvs = json.load(json_file)

# %%
USER_GENERATED_INPUT = {
    'General Description': 'The data in my .csv file contains information about financial loans made to businesses.',
    'BorrowerName': 'BorrowerName contains the name of the Business that applied for the loan.',
    'BusinessType': 'BusinessType contains the type of business (i.e., Corp, Partnership, LLC, etc.)',
    'LoanNumber': 'LoanNumber contains the unique identifier for the loan.',
    'CurrentApprovalAmount': 'CurrentApprovalAmount contains the financial amount of the loan.',
    'JobsReported': 'JobsReported contains the number of jobs the loan supports.',
    'ProjectState': 'ProjectState contains the state where the funds will be used.',
    'OriginatingLender': 'OriginatingLender contains the lender that originated the loan.',
    'UTILITIES_PROCEED': 'UTILITIES_PROCEED contains the amount of the loan the borrower said they will use to pay utilities.',
    'PAYROLL_PROCEED': 'PAYROLL_PROCEED contains the amount of the loan the borrower said they will use for payroll.',
    'MORTGAGE_INTEREST_PROCEED': 'MORTGAGE_INTEREST_PROCEED contains the amount of the loan the borrower said they will use to pay mortgage interest.',
    'RENT_PROCEED': 'RENT_PROCEED contains the amount of the loan the borrower said they will use to pay rent.',
    'REFINANCE_EIDL_PROCEED': 'REFINANCE_EIDL_PROCEED contains the amount of the loan the borrower said they will use to refinance an existing loan.',
    'HEALTH_CARE_PROCEED': 'HEALTH_CARE_PROCEED contains the amount of the loan the borrower said they will use to pay employee health care.',
    'DEBT_INTEREST_PROCEED': 'DEBT_INTEREST_PROCEED contains the amount of the loan the borrower said they will use to pay debt interest.'
}

# %%
# define the columns of interest
COLUMNS=list(USER_GENERATED_INPUT.keys())[1:]

# %%
print(COLUMNS)
# Out:
# ['BorrowerName', 'BusinessType', 'LoanNumber', 'CurrentApprovalAmount', 'JobsReported', 'ProjectState', 'OriginatingLender', 'UTILITIES_PROCEED', 'PAYROLL_PROCEED', 'MORTGAGE_INTEREST_PROCEED', 'RENT_PROCEED', 'REFINANCE_EIDL_PROCEED', 'HEALTH_CARE_PROCEED', 'DEBT_INTEREST_PROCEED']

# %%
df = pd.read_csv("../data/csv/ppp_loan_data.csv")[COLUMNS]

# %%
buffer = io.StringIO()
df.info(buf=buffer)

df_info = buffer.getvalue()

# %%
desc = df.describe(percentiles=[0.1, 0.25, 0.5, 0.75, 0.9, 0.95, 0.99])

# %%
desc
# Out:
#          LoanNumber  CurrentApprovalAmount   JobsReported  UTILITIES_PROCEED  \
# count  9.685250e+05           9.685250e+05  968524.000000       3.393690e+05
# mean   5.427141e+09           5.306195e+05      51.886593       1.493001e+04
# std    2.551309e+09           7.378860e+05      67.552670       8.493718e+04
# min    1.000007e+09           1.500000e+05       0.000000       0.000000e+00
# 10%    1.864502e+09           1.669620e+05      12.000000       1.000000e+00
# 25%    3.271119e+09           2.004000e+05      18.000000       1.000000e+00
# 50%    5.400677e+09           2.950000e+05      30.000000       1.000000e+00
# 75%    7.546308e+09           5.393829e+05      54.000000       4.500000e+03
# 90%    9.048413e+09           1.084455e+06     110.000000       3.074608e+04
# 95%    9.520696e+09           1.702404e+06     175.000000       6.320000e+04
# 99%    9.909277e+09           3.750000e+06     396.000000       2.452928e+05
# max    9.999007e+09           1.000000e+07     500.000000       1.000000e+07
#
#        PAYROLL_PROCEED  MORTGAGE_INTEREST_PROCEED  RENT_PROCEED  \
# count     9.666930e+05               4.617200e+04  9.953000e+04
# mean      5.148761e+05               4.816586e+04  5.619698e+04
# std       7.140555e+05               1.591102e+05  1.113768e+05
# min       0.000000e+00               0.000000e+00  0.000000e+00
# 10%       1.625000e+05               0.000000e+00  4.095800e+03
# 25%       1.956000e+05               0.000000e+00  1.353293e+04
# 50%       2.870770e+05               1.000000e+04  2.887750e+04
# 75%       5.246020e+05               4.025978e+04  5.625000e+04
# 90%       1.052715e+06               1.078968e+05  1.166324e+05
# 95%       1.649693e+06               2.030549e+05  1.950000e+05
# 99%       3.597014e+06               6.089184e+05  4.999710e+05
# max       1.000000e+07               1.000000e+07  5.518278e+06
#
#        REFINANCE_EIDL_PROCEED  HEALTH_CARE_PROCEED  DEBT_INTEREST_PROCEED
# count            2.284800e+04         5.744100e+04           3.170700e+04
# mean             6.899911e+03         4.686451e+04           1.436319e+04
# std              6.215009e+04         1.029147e+05           5.550163e+04
# min              0.000000e+00         0.000000e+00           0.000000e+00
# 10%              0.000000e+00         1.000000e+00           0.000000e+00
# 25%              0.000000e+00         8.000000e+03           0.000000e+00
# 50%              0.000000e+00         1.944400e+04           5.000000e+02
# 75%              0.000000e+00         4.400000e+04           9.915105e+03
# 90%              0.000000e+00         1.020180e+05           3.187840e+04
# 95%              1.000000e+04         1.836000e+05           6.237096e+04
# 99%              2.000000e+05         4.813948e+05           2.111298e+05
# max              2.951590e+06         3.880000e+06           2.497617e+06

# %%
desc_cat = df.describe(include='object')

# %%
desc_cat
# Out:
#                          BorrowerName BusinessType ProjectState  \
# count                          968521       967806       968516
# unique                         857334           25           56
# top     FIRST UNITED METHODIST CHURCH  Corporation           CA
# freq                               40       418313       130614
#
#                                 OriginatingLender
# count                                      968525
# unique                                       4236
# top     JPMorgan Chase Bank, National Association
# freq                                        53539

# %%
def generate_csv_summary(data: pd.DataFrame) -> Dict[str, pd.DataFrame]:
    """
    Generate the data summaries.
    """
    buffer = io.StringIO()
    data.info(buf=buffer)

    df_info = buffer.getvalue()
    desc_numeric = data.describe(percentiles=[0.1, 0.25, 0.5, 0.75, 0.9, 0.95, 0.99])
    desc_categorical = data.describe(include='object')

    return {
        "general_info": df_info,
        "description_numeric": desc_numeric,
        "description_categorical": desc_categorical
    }

# %%
def generate_discovery_prompt(user_input: Dict[str, str], df_info: pd.DataFrame, desc_numeric: pd.DataFrame, desc_categorical: pd.DataFrame) ->str:
    """
    Generate the initial discovery prompt.
    """

    descriptions = ""
    for col in desc_numeric.columns:
        descriptions += f"{col}: {user_input[col]} \n It has the following distribution: {desc_numeric[col]} \n\n"

    for col in desc_categorical.columns:
        descriptions += f"{col}: {user_input[col]} \n It has the following distribution: {desc_categorical[col]} \n\n"

    prompt = f"""
You are a data scientist with experience creating Neo4j
graph data models from tabular data. I am a developer who will be
creating a Neo4j graph data model from the data in a single .csv file.

I want you to perform a preliminary analysis on my data to help us understand
its characteristics before we brainstorm about the graph data model.

This is a general description of the data:
{user_input['General Description']}

The following is summary of the data features, data types, and missing values:
{df_info}

The following is a description of each feature in the data:
{descriptions}

Provide me with your preliminary analysis of this data. What are important
overall details about the data? What are the most important features?

Do not return your suggestion for the Neo4j graph data model
yet. We will do that in the next step.
            """
    
    return prompt

# %%
prompt = generate_discovery_prompt(user_input=USER_GENERATED_INPUT, df_info=df_info, desc_numeric=desc, desc_categorical=desc_cat)

# %%
print(prompt)
# Out:
# You are a data scientist with experience creating Neo4j
# graph data models from tabular data. I am a developer who will be
# creating a Neo4j graph data model from the data in a single .csv file.
#
# I want you to perform a preliminary analysis on my data to help us understand
# its characteristics before we brainstorm about the graph data model.
#
# This is a general description of the data:
# The data in my .csv file contains information about financial loans made to businesses.
#
# The following is summary of the data features, data types, and missing values:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 968525 entries, 0 to 968524
# Data columns (total 14 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   BorrowerName               968521 non-null  object
#  1   BusinessType               967806 non-null  object
#  2   LoanNumber                 968525 non-null  int64
#  3   CurrentApprovalAmount      968525 non-null  float64
#  4   JobsReported               968524 non-null  float64
#  5   ProjectState               968516 non-null  object
#  6   OriginatingLender          968525 non-null  object
#  7   UTILITIES_PROCEED          339369 non-null  float64
#  8   PAYROLL_PROCEED            966693 non-null  float64
#  9   MORTGAGE_INTEREST_PROCEED  46172 non-null   float64
#  10  RENT_PROCEED               99530 non-null   float64
#  11  REFINANCE_EIDL_PROCEED     22848 non-null   float64
#  12  HEALTH_CARE_PROCEED        57441 non-null   float64
#  13  DEBT_INTEREST_PROCEED      31707 non-null   float64
# dtypes: float64(9), int64(1), object(4)
# memory usage: 103.4+ MB
#
#
# The following is a description of each feature in the data:
# LoanNumber: LoanNumber contains the unique identifier for the loan.
#  It has the following distribution: count    9.685250e+05
# mean     5.427141e+09
# std      2.551309e+09
# min      1.000007e+09
# 10%      1.864502e+09
# 25%      3.271119e+09
# 50%      5.400677e+09
# 75%      7.546308e+09
# 90%      9.048413e+09
# 95%      9.520696e+09
# 99%      9.909277e+09
# max      9.999007e+09
# Name: LoanNumber, dtype: float64
#
# CurrentApprovalAmount: CurrentApprovalAmount contains the financial amount of the loan.
#  It has the following distribution: count    9.685250e+05
# mean     5.306195e+05
# std      7.378860e+05
# min      1.500000e+05
# 10%      1.669620e+05
# 25%      2.004000e+05
# 50%      2.950000e+05
# 75%      5.393829e+05
# 90%      1.084455e+06
# 95%      1.702404e+06
# 99%      3.750000e+06
# max      1.000000e+07
# Name: CurrentApprovalAmount, dtype: float64
#
# JobsReported: JobsReported contains the number of jobs the loan supports.
#  It has the following distribution: count    968524.000000
# mean         51.886593
# std          67.552670
# min           0.000000
# 10%          12.000000
# 25%          18.000000
# 50%          30.000000
# 75%          54.000000
# 90%         110.000000
# 95%         175.000000
# 99%         396.000000
# max         500.000000
# Name: JobsReported, dtype: float64
#
# UTILITIES_PROCEED: UTILITIES_PROCEED contains the amount of the loan the borrower said they will use to pay utilities.
#  It has the following distribution: count    3.393690e+05
# mean     1.493001e+04
# std      8.493718e+04
# min      0.000000e+00
# 10%      1.000000e+00
# 25%      1.000000e+00
# 50%      1.000000e+00
# 75%      4.500000e+03
# 90%      3.074608e+04
# 95%      6.320000e+04
# 99%      2.452928e+05
# max      1.000000e+07
# Name: UTILITIES_PROCEED, dtype: float64
#
# PAYROLL_PROCEED: PAYROLL_PROCEED contains the amount of the loan the borrower said they will use for payroll.
#  It has the following distribution: count    9.666930e+05
# mean     5.148761e+05
# std      7.140555e+05
# min      0.000000e+00
# 10%      1.625000e+05
# 25%      1.956000e+05
# 50%      2.870770e+05
# 75%      5.246020e+05
# 90%      1.052715e+06
# 95%      1.649693e+06
# 99%      3.597014e+06
# max      1.000000e+07
# Name: PAYROLL_PROCEED, dtype: float64
#
# MORTGAGE_INTEREST_PROCEED: MORTGAGE_INTEREST_PROCEED contains the amount of the loan the borrower said they will use to pay mortgage interest.
#  It has the following distribution: count    4.617200e+04
# mean     4.816586e+04
# std      1.591102e+05
# min      0.000000e+00
# 10%      0.000000e+00
# 25%      0.000000e+00
# 50%      1.000000e+04
# 75%      4.025978e+04
# 90%      1.078968e+05
# 95%      2.030549e+05
# 99%      6.089184e+05
# max      1.000000e+07
# Name: MORTGAGE_INTEREST_PROCEED, dtype: float64
#
# RENT_PROCEED: RENT_PROCEED contains the amount of the loan the borrower said they will use to pay rent.
#  It has the following distribution: count    9.953000e+04
# mean     5.619698e+04
# std      1.113768e+05
# min      0.000000e+00
# 10%      4.095800e+03
# 25%      1.353293e+04
# 50%      2.887750e+04
# 75%      5.625000e+04
# 90%      1.166324e+05
# 95%      1.950000e+05
# 99%      4.999710e+05
# max      5.518278e+06
# Name: RENT_PROCEED, dtype: float64
#
# REFINANCE_EIDL_PROCEED: REFINANCE_EIDL_PROCEED contains the amount of the loan the borrower said they will use to refinance an existing loan.
#  It has the following distribution: count    2.284800e+04
# mean     6.899911e+03
# std      6.215009e+04
# min      0.000000e+00
# 10%      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      0.000000e+00
# 90%      0.000000e+00
# 95%      1.000000e+04
# 99%      2.000000e+05
# max      2.951590e+06
# Name: REFINANCE_EIDL_PROCEED, dtype: float64
#
# HEALTH_CARE_PROCEED: HEALTH_CARE_PROCEED contains the amount of the loan the borrower said they will use to pay employee health care.
#  It has the following distribution: count    5.744100e+04
# mean     4.686451e+04
# std      1.029147e+05
# min      0.000000e+00
# 10%      1.000000e+00
# 25%      8.000000e+03
# 50%      1.944400e+04
# 75%      4.400000e+04
# 90%      1.020180e+05
# 95%      1.836000e+05
# 99%      4.813948e+05
# max      3.880000e+06
# Name: HEALTH_CARE_PROCEED, dtype: float64
#
# DEBT_INTEREST_PROCEED: DEBT_INTEREST_PROCEED contains the amount of the loan the borrower said they will use to pay debt interest.
#  It has the following distribution: count    3.170700e+04
# mean     1.436319e+04
# std      5.550163e+04
# min      0.000000e+00
# 10%      0.000000e+00
# 25%      0.000000e+00
# 50%      5.000000e+02
# 75%      9.915105e+03
# 90%      3.187840e+04
# 95%      6.237096e+04
# 99%      2.111298e+05
# max      2.497617e+06
# Name: DEBT_INTEREST_PROCEED, dtype: float64
#
# BorrowerName: BorrowerName contains the name of the Business that applied for the loan.
#  It has the following distribution: count                            968521
# unique                           857334
# top       FIRST UNITED METHODIST CHURCH
# freq                                 40
# Name: BorrowerName, dtype: object
#
# BusinessType: BusinessType contains the type of business (i.e., Corp, Partnership, LLC, etc.)
#  It has the following distribution: count          967806
# unique             25
# top       Corporation
# freq           418313
# Name: BusinessType, dtype: object
#
# ProjectState: ProjectState contains the state where the funds will be used.
#  It has the following distribution: count     968516
# unique        56
# top           CA
# freq      130614
# Name: ProjectState, dtype: object
#
# OriginatingLender: OriginatingLender contains the lender that originated the loan.
#  It has the following distribution: count                                        968525
# unique                                         4236
# top       JPMorgan Chase Bank, National Association
# freq                                          53539
# Name: OriginatingLender, dtype: object
#
#
#
# Provide me with your preliminary analysis of this data. What are important
# overall details about the data? What are the most important features?
#
# Do not return your suggestion for the Neo4j graph data model
# yet. We will do that in the next step.

# %%
def generate_initial_data_model_prompt() -> str:
    """
    Generate the initial data model request prompt.
    """
    prompt = """
That is a very helpful. Based upon your of the data in my .csv and your
knowledge of high-quality Neo4j graph data models, I would like you to return your
suggestion for translating the data in my .csv into a Neo4j graph data model.

Once built, the Neo4j graph will be used to identify
potential fraud. We have not identified fraudulent loans yet
and so do not have that information in this data.

Please return the following:
Suggested Nodes and their properties, along with your reasoning for each
Relationships and their properties, along with your reasoning for each
Include only nodes, relationships, and properties derived from
features from my .csv file.

Do not return any code to create the data model. I only want to
focus on the proposed nodes, relationships, and properties with
your explanation for why you suggested each.

Return your data model in JSON format. 
Format nodes as:
{
    "Label": <node label>,
    "Properties": <list of node properties>,
    "Reasoning": <reasoning for why this decision was made.>
}
Format relationships as:
{
      "Label": <relationship label>,
      "Properties": <list of relationship properties>,
      "From": <the node this relationship begins>,
      "To": <the node this relationship ends>,
      "Reasoning": <reasoning for why this decision was made.>
    }
"""
    return prompt

# %%
def generate_data_model_iteration_prompt() -> str:
    """
    Generate the prompt to iterate on the previous data model.
    """

    prompt = """
That is a good start and very helpful.

Based on your experience building high-quality graph data
models, are there any improvements you would suggest?

For example, are there any node properties that should
be converted to separate, additional nodes in the data model?

Please return an updated graph data model with your suggested improvements.
Reference only features available in the original .csv file.

Do not return any code to create the data model. I only want to
focus on the proposed nodes, relationships, and properties.

Return your data model in JSON format.
Format nodes as:
{
    "Label": <node label>,
    "Properties": <list of node properties>,
    "Reasoning": <reasoning for why this decision was made.>
}
Format relationships as:
{
      "Label": <relationship label>,
      "Properties": <list of relationship properties>,
      "From": <the node this relationship begins>,
      "To": <the node this relationship ends>,
      "Reasoning": <reasoning for why this decision was made.>
    }
"""
    
    return prompt

# %% [markdown]
# # Use Methods

# %%
llm = LLM()
# Out:
# fa1c4830d14f4703abadfb5ae9e44629 https://kss-neoconverse.openai.azure.com/ neoconverse-gpt4

# %%
summaries = generate_csv_summary(data=df)

# %%
discovery_prompt = generate_discovery_prompt(user_input=USER_GENERATED_INPUT, 
                                               df_info=summaries['general_info'], 
                                               desc_numeric=summaries['description_numeric'], 
                                               desc_categorical=summaries['description_categorical'])

# %%
discovery_response = llm.get_response(discovery_prompt)

# %%
print(discovery_response)
# Out:
# Your data set is quite extensive, comprising of 968,525 entries which indicates it has rich information for analysis. It contains a mix of categorical and numerical data types which will be useful for different types of analysis and modeling. The memory usage is also substantial at 103.4+ MB.
#
# The data consists of 14 features related to financial loans made to businesses, which includes borrower details, loan details, business details, and how the loan amount is planned to be used.
#
# Let's go over some important points about the dataset:
#
# 1. Missing values: Some columns have missing values, notably UTILITIES_PROCEED, PAYROLL_PROCEED, MORTGAGE_INTEREST_PROCEED, RENT_PROCEED, REFINANCE_EIDL_PROCEED, HEALTH_CARE_PROCEED and DEBT_INTEREST_PROCEED. You may want to think about how to handle these missing values depending on the analysis you want to perform.
#
# 2. Unique Identifiers: The LoanNumber feature can be used as a unique identifier for each loan as it is unique for each entry.
#
# 3. Categorical Features: BorrowerName, BusinessType, ProjectState, and OriginatingLender are all categorical variables. These can be important for analysis such as segmentation or for understanding patterns in loan distribution.
#
# 4. Numerical Features: CurrentApprovalAmount, JobsReported, UTILITIES_PROCEED, PAYROLL_PROCEED, MORTGAGE_INTEREST_PROCEED, RENT_PROCEED, REFINANCE_EIDL_PROCEED, HEALTH_CARE_PROCEED and DEBT_INTEREST_PROCEED are numerical variables. They can provide insights into the amount of loans approved and how they are intended to be used.
#
# 5. Loan Usage: The features detailing loan usage (like UTILITIES_PROCEED, PAYROLL_PROCEED, etc.) provide a breakdown of how businesses plan to use their loans. This could be important for understanding the needs of businesses and the economic impacts of these loans.
#
# 6. The most frequent business type is 'Corporation' and the state with the highest frequency of loans is California according to the 'BusinessType' and 'ProjectState' columns respectively.
#
# 7. The most frequent originating lender is 'JPMorgan Chase Bank, National Association'.
#
# In terms of importance, all features provide valuable information depending on the context of your analysis. However, 'CurrentApprovalAmount', 'JobsReported', 'BusinessType', 'ProjectState', 'OriginatingLender' and the breakdown of how the loan is used would likely be key features for most analyses.
#
# Remember, the importance of features can also greatly depend on the specific questions you are trying to answer with your data.

# %%
initial_data_model_response = llm.get_response(generate_initial_data_model_prompt())

# %%
print(initial_data_model_response)
# Out:
# Absolutely, I'd be happy to provide a suggestion for translating your CSV data into a high-quality Neo4j graph data model. Here is the proposed model:
#
# ```json
# {
#   "Nodes": [
#     {
#       "Label": "Loan",
#       "Properties": ["LoanNumber"],
#       "Reasoning": "The property 'LoanNumber' is essential to uniquely identify each loan."
#     },
#     {
#       "Label": "Business",
#       "Properties": ["BorrowerName"],
#       "Reasoning": "The borrower's name is important to associate loans with businesses."
#     },
#     {
#       "Label": "BusinessType",
#       "Properties": ["BusinessType"],
#       "Reasoning": "This node is created to capture the type of business. It can help identify patterns among the types of businesses that apply for loans."
#     },
#     {
#       "Label": "Lender",
#       "Properties": ["OriginatingLender"],
#       "Reasoning": "The originating lender is important to track where the loan came from."
#     },
#     {
#       "Label": "State",
#       "Properties": ["ProjectState"],
#       "Reasoning": "The state is important to capture the geographical location of the business."
#     },
#     {
#       "Label": "ProceedType",
#       "Properties": ["LoanProceedType"],
#       "Reasoning": "This node is created to capture the type of proceeds. This can help identify patterns in how loan funds are used."
#     },
#     {
#       "Label": "Approval",
#       "Properties": ["CurrentApprovalAmount"],
#       "Reasoning": "By separating 'CurrentApprovalAmount' into its own node, we can track changes in approval amounts over time and analyze relationships better."
#     },
#     {
#       "Label": "Jobs",
#       "Properties": ["JobsReported"],
#       "Reasoning": "Moving 'JobsReported' into its own node gives us the flexibility to track job creation in relation to other nodes and relationships."
#     }
#   ],
#   "Relationships": [
#     {
#       "Label": "LOANED_TO",
#       "Properties": [],
#       "From": "Loan",
#       "To": "Business",
#       "Reasoning": "This relationship represents the loan being given to a business."
#     },
#     {
#       "Label": "ORIGINATED_FROM",
#       "Properties": [],
#       "From": "Loan",
#       "To": "Lender",
#       "Reasoning": "This relationship shows where the loan originated."
#     },
#     {
#       "Label": "LOCATED_IN",
#       "Properties": [],
#       "From": "Business",
#       "To": "State",
#       "Reasoning": "This relationship helps to place the businesses geographically."
#     },
#     {
#       "Label": "OF_TYPE",
#       "Properties": [],
#       "From": "Business",
#       "To": "BusinessType",
#       "Reasoning": "This relationship links businesses to their types, which can be useful for pattern detection."
#     },
#     {
#       "Label": "USED_FOR",
#       "Properties": ["LoanAmount"],
#       "From": "Loan",
#       "To": "ProceedType",
#       "Reasoning": "This relationship links loans to the types of proceeds with the amount used for each. This can help identify unusual allocation of funds."
#     },
#     {
#       "Label": "HAS_APPROVAL",
#       "Properties": [],
#       "From": "Loan",
#       "To": "Approval",
#       "Reasoning": "This new relationship links the loan to its approval amount."
#     },
#     {
#       "Label": "CREATED_JOBS",
#       "Properties": [],
#       "From": "Loan",
#       "To": "Jobs",
#       "Reasoning": "This new relationship links the loan to its impact on job creation."
#     }
#   ]
# }
# ```
# This model should provide a comprehensive view of the data, capturing all important aspects and relationships between entities. This should enable effective analysis for potential fraud detection.

# %%
second_data_model_response = llm.get_response(generate_data_model_iteration_prompt())

# %%
print(second_data_model_response)
# Out:
# Absolutely, it's a good practice to keep refining the graph data model for optimal analysis. I have a couple of improvements to recommend based on the data provided. For instance, the property 'CurrentApprovalAmount' could be converted to a separate node 'ApprovalAmount'. Similarly, 'JobsReported' could be converted into 'Jobs'. This can help in creating more explicit relationships in the graph. Here is the improved model:
#
# ```json
# {
#   "Nodes": [
#     {
#       "Label": "Loan",
#       "Properties": ["LoanNumber"],
#       "Reasoning": "The property 'LoanNumber' is essential to uniquely identify each loan."
#     },
#     {
#       "Label": "Business",
#       "Properties": ["BorrowerName"],
#       "Reasoning": "The borrower's name is important to associate loans with businesses."
#     },
#     {
#       "Label": "BusinessType",
#       "Properties": ["BusinessType"],
#       "Reasoning": "This node is created to capture the type of business. It can help identify patterns among the types of businesses that apply for loans."
#     },
#     {
#       "Label": "Lender",
#       "Properties": ["OriginatingLender"],
#       "Reasoning": "The originating lender is important to track where the loan came from."
#     },
#     {
#       "Label": "State",
#       "Properties": ["ProjectState"],
#       "Reasoning": "The state is important to capture the geographical location of the business."
#     },
#     {
#       "Label": "ProceedType",
#       "Properties": ["LoanProceedType"],
#       "Reasoning": "This node is created to capture the type of proceeds. This can help identify patterns in how loan funds are used."
#     },
#     {
#       "Label": "ApprovalAmount",
#       "Properties": ["CurrentApprovalAmount"],
#       "Reasoning": "By converting 'CurrentApprovalAmount' into its own node, we can track changes in approval amounts over time and analyze relationships better."
#     },
#     {
#       "Label": "Jobs",
#       "Properties": ["JobsReported"],
#       "Reasoning": "Converting 'JobsReported' into its own node gives us the flexibility to track job creation in relation to other nodes and relationships."
#     }
#   ],
#   "Relationships": [
#     {
#       "Label": "LOANED_TO",
#       "Properties": [],
#       "From": "Loan",
#       "To": "Business",
#       "Reasoning": "This relationship represents the loan being given to a business."
#     },
#     {
#       "Label": "ORIGINATED_FROM",
#       "Properties": [],
#       "From": "Loan",
#       "To": "Lender",
#       "Reasoning": "This relationship shows where the loan originated."
#     },
#     {
#       "Label": "LOCATED_IN",
#       "Properties": [],
#       "From": "Business",
#       "To": "State",
#       "Reasoning": "This relationship helps to place the businesses geographically."
#     },
#     {
#       "Label": "OF_TYPE",
#       "Properties": [],
#       "From": "Business",
#       "To": "BusinessType",
#       "Reasoning": "This relationship links businesses to their types, which can be useful for pattern detection."
#     },
#     {
#       "Label": "USED_FOR",
#       "Properties": ["LoanAmount"],
#       "From": "Loan",
#       "To": "ProceedType",
#       "Reasoning": "This relationship links loans to the types of proceeds with the amount used for each. This can help identify unusual allocation of funds."
#     },
#     {
#       "Label": "HAS_APPROVAL_AMOUNT",
#       "Properties": [],
#       "From": "Loan",
#       "To": "ApprovalAmount",
#       "Reasoning": "This new relationship links the loan to its approval amount. It is especially useful for tracking changes in approval amounts over time."
#     },
#     {
#       "Label": "CREATED_JOBS",
#       "Properties": [],
#       "From": "Loan",
#       "To": "Jobs",
#       "Reasoning": "This new relationship links the loan to its impact on job creation. This can help identify patterns and correlations between loans and job creation."
#     }
#   ]
# }
# ```
# This model should provide a more granular view of the data, facilitating more detailed and insightful analysis, especially in the context of fraud detection.
